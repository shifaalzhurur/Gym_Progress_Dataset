# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data=pd.read_csv("Gym_Progress_Dataset (1).csv")

# %%
df=pd.DataFrame(data)

# %%
df
# Out:
#             Day  Weight_kg  Calories_Intake  Protein_Intake_g  \
# 0    2025-01-01       71.5             3209                70
# 1    2025-01-02       69.6             2584               150
# 2    2025-01-03       71.9             2927               148
# 3    2025-01-04       74.6             3216                85
# 4    2025-01-05       69.3             2045               145
# ..          ...        ...              ...               ...
# 195  2025-07-15       71.2             3316               100
# 196  2025-07-16       67.3             2898                70
# 197  2025-07-17       70.5             2212                54
# 198  2025-07-18       70.2             3199               141
# 199  2025-07-19       66.6             3243               110
#
#      Workout_Duration_min  Steps_Walked
# 0                      41          6820
# 1                      40          4898
# 2                      89          9546
# 3                      20          2077
# ...

# %%
data.head()
# Out:
#           Day  Weight_kg  Calories_Intake  Protein_Intake_g  \
# 0  2025-01-01       71.5             3209                70
# 1  2025-01-02       69.6             2584               150
# 2  2025-01-03       71.9             2927               148
# 3  2025-01-04       74.6             3216                85
# 4  2025-01-05       69.3             2045               145
#
#    Workout_Duration_min  Steps_Walked
# 0                    41          6820
# 1                    40          4898
# 2                    89          9546
# 3                    20          2077
# 4                    24          9577

# %%
data.tail()
# Out:
#             Day  Weight_kg  Calories_Intake  Protein_Intake_g  \
# 195  2025-07-15       71.2             3316               100
# 196  2025-07-16       67.3             2898                70
# 197  2025-07-17       70.5             2212                54
# 198  2025-07-18       70.2             3199               141
# 199  2025-07-19       66.6             3243               110
#
#      Workout_Duration_min  Steps_Walked
# 195                    30         13404
# 196                    33         11181
# 197                    79         12454
# 198                    49          4482
# 199                    54         10058

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 6 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Day                   200 non-null    object
#  1   Weight_kg             200 non-null    float64
#  2   Calories_Intake       200 non-null    int64
#  3   Protein_Intake_g      200 non-null    int64
#  4   Workout_Duration_min  200 non-null    int64
#  5   Steps_Walked          200 non-null    int64
# dtypes: float64(1), int64(4), object(1)
# memory usage: 9.5+ KB

# %%
data.describe()
# Out:
#         Weight_kg  Calories_Intake  Protein_Intake_g  Workout_Duration_min  \
# count  200.000000       200.000000        200.000000            200.000000
# mean    69.878000      2703.915000        115.000000             66.555000
# std      2.795656       466.300114         37.673952             29.866486
# min     62.100000      1804.000000         50.000000             20.000000
# 25%     67.900000      2333.750000         82.750000             40.750000
# 50%     70.000000      2699.000000        114.500000             66.000000
# 75%     71.500000      3049.500000        148.000000             92.000000
# max     78.200000      3498.000000        178.000000            119.000000
#
#        Steps_Walked
# count    200.000000
# mean    8352.705000
# std     3701.129242
# min     2077.000000
# 25%     5215.250000
# 50%     8004.000000
# 75%    11994.500000
# max    14999.000000

# %%
df.isna().sum()
# Out:
# Day                     0
# Weight_kg               0
# Calories_Intake         0
# Protein_Intake_g        0
# Workout_Duration_min    0
# Steps_Walked            0
# dtype: int64

# %%
data.dropna()
# Out:
#             Day  Weight_kg  Calories_Intake  Protein_Intake_g  \
# 0    2025-01-01       71.5             3209                70
# 1    2025-01-02       69.6             2584               150
# 2    2025-01-03       71.9             2927               148
# 3    2025-01-04       74.6             3216                85
# 4    2025-01-05       69.3             2045               145
# ..          ...        ...              ...               ...
# 195  2025-07-15       71.2             3316               100
# 196  2025-07-16       67.3             2898                70
# 197  2025-07-17       70.5             2212                54
# 198  2025-07-18       70.2             3199               141
# 199  2025-07-19       66.6             3243               110
#
#      Workout_Duration_min  Steps_Walked
# 0                      41          6820
# 1                      40          4898
# 2                      89          9546
# 3                      20          2077
# ...

# %%
data['Weight_kg'].hist()
plt.title("Gym")
plt.show()

# %%
plt.scatter(data['Calories_Intake'],data['Weight_kg'])
plt.xlabel("Calories")
plt.ylabel("Weight")
plt.show()

# %%
data=[data['Weight_kg'].mean(),data['Calories_Intake'].mean(),data['Steps_Walked'].mean()]
labels=['Weight_kg','Calories_Intake','Steps_Walked']
plt.pie(data,labels=labels,autopct= '%1.1f%%')
plt.title("Fitness")
plt.show()

# %%
import seaborn as sns
sns.heatmap(df.corr(numeric_only=True), annot=True)
plt.show()
